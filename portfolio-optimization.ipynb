# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
import gurobipy as gp
from gurobipy import GRB

# %% [markdown]
# # Data Preprocessing

# %%
# Load data, selecting data from the 25840th till the 51657th row
df = pd.read_csv(
    '100_Portfolios_10x10_Daily.csv', 
    skiprows=25817, 
    nrows=(51613 - 25818), 
    header=0,    # Set first row as the column
    index_col=0  # Set date as the index
)

# Changing the index to datetime format
df.index = pd.to_datetime(df.index, format='%Y%m%d')

# Retrieving data dated between 2022-12-29 and 2024-07-31
df = df[(df.index >= '2022-12-29') & (df.index <= '2024-07-31')]

# Drop 'ME9 BM10' due to presence of missing values
df = df.drop('ME9 BM10', axis=1)

df.head()
# Out:
#             SMALL LoBM  ME1 BM2  ME1 BM3  ME1 BM4  ME1 BM5  ME1 BM6  ME1 BM7  \
# 2022-12-29        3.61     3.91     5.68     4.66     3.95     4.39     3.51
# 2022-12-30        3.57     3.06     4.97     1.58     2.36     1.87     2.29
# 2023-01-03       -1.04     0.10     0.86     2.24     3.95     1.57     6.37
# 2023-01-04        3.58     3.14     5.35     4.73     2.72     4.14     3.74
# 2023-01-05        0.36    -1.45     0.48     0.54     1.93    -0.08    -0.35
#
#             ME1 BM8  ME1 BM9  SMALL HiBM  ...  BIG LoBM  ME10 BM2  ME10 BM3  \
# 2022-12-29     4.88     2.82        2.80  ...      2.19      1.94      1.25
# 2022-12-30     2.49     1.69        1.35  ...     -0.42     -0.45     -0.36
# 2023-01-03     2.27     1.88        1.91  ...     -0.47      0.57      0.30
# 2023-01-04     2.38     2.18        2.89  ...      1.28      1.04      0.81
# 2023-01-05     0.97     1.39        0.39  ...     -1.68     -1.11     -1.07
#
#             ME10 BM4  ME10 BM5  ME10 BM6  ME10 BM7  ME10 BM8  ME10 BM9  \
# 2022-12-29      1.14      1.12      1.30      0.76      1.24      1.38
# 2022-12-30     -0.34     -0.50     -0.08      0.20      0.13     -0.23
# 2023-01-03     -0.86      0.08      0.54     -0.73     -1.54      0.62
# 2023-01-04      0.29      0.58      2.28      0.68      0.32      1.56
# 2023-01-05     -1.81     -0.60     -0.62     -0.07      0.41     -0.72
#
#             BIG HiBM
# 2022-12-29      1.04
# 2022-12-30     -0.20
# 2023-01-03      0.15
# 2023-01-04      1.66
# 2023-01-05     -0.40
#
# [5 rows x 99 columns]

# %%
# Confirm data structure & absence of missing values
df.replace([-99.99, -999], np.nan, inplace=True)  # inplace = True to modify the original DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 398 entries, 2022-12-29 to 2024-07-31
# Data columns (total 99 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SMALL LoBM  398 non-null    float64
#  1   ME1 BM2     398 non-null    float64
#  2   ME1 BM3     398 non-null    float64
#  3   ME1 BM4     398 non-null    float64
#  4   ME1 BM5     398 non-null    float64
#  5   ME1 BM6     398 non-null    float64
#  6   ME1 BM7     398 non-null    float64
#  7   ME1 BM8     398 non-null    float64
#  8   ME1 BM9     398 non-null    float64
#  9   SMALL HiBM  398 non-null    float64
#  10  ME2 BM1     398 non-null    float64
#  11  ME2 BM2     398 non-null    float64
#  12  ME2 BM3     398 non-null    float64
#  13  ME2 BM4     398 non-null    float64
#  14  ME2 BM5     398 non-null    float64
#  15  ME2 BM6     398 non-null    float64
#  16  ME2 BM7     398 non-null    float64
#  17  ME2 BM8     398 non-null    float64
#  18  ME2 BM9     398 non-null    float64
#  19  ME2 BM10    398 non-null    float64
#  20  ME3 BM1     398 non-null    float64
#  21  ME3 BM2     398 non-null    float64
#  22  ME3 BM3     398 non-null    float64
#  23  ME3 BM4     398 non-null    float64
#  24  ME3 BM5     398 non-null    float64
#  25  ME3 BM6     398 non-null    float64
#  26  ME3 BM7     398 non-null    float64
#  27  ME3 BM8     398 non-null    float64
#  28  ME3 BM9     398 non-null    float64
#  29  ME3 BM10    398 non-null    float64
#  30  ME4 BM1     398 non-null    float64
#  31  ME4 BM2     398 non-null    float64
#  32  ME4 BM3     398 non-null    float64
#  33  ME4 BM4     398 non-null    float64
#  34  ME4 BM5     398 non-null    float64
#  35  ME4 BM6     398 non-null    float64
#  36  ME4 BM7     398 non-null    float64
#  37  ME4 BM8     398 non-null    float64
#  38  ME4 BM9     398 non-null    float64
#  39  ME4 BM10    398 non-null    float64
#  40  ME5 BM1     398 non-null    float64
#  41  ME5 BM2     398 non-null    float64
#  42  ME5 BM3     398 non-null    float64
#  43  ME5 BM4     398 non-null    float64
#  44  ME5 BM5     398 non-null    float64
#  45  ME5 BM6     398 non-null    float64
#  46  ME5 BM7     398 non-null    float64
#  47  ME5 BM8     398 non-null    float64
#  48  ME5 BM9     398 non-null    float64
#  49  ME5 BM10    398 non-null    float64
#  50  ME6 BM1     398 non-null    float64
#  51  ME6 BM2     398 non-null    float64
#  52  ME6 BM3     398 non-null    float64
#  53  ME6 BM4     398 non-null    float64
#  54  ME6 BM5     398 non-null    float64
#  55  ME6 BM6     398 non-null    float64
#  56  ME6 BM7     398 non-null    float64
#  57  ME6 BM8     398 non-null    float64
#  58  ME6 BM9     398 non-null    float64
#  59  ME6 BM10    398 non-null    float64
#  60  ME7 BM1     398 non-null    float64
#  61  ME7 BM2     398 non-null    float64
#  62  ME7 BM3     398 non-null    float64
#  63  ME7 BM4     398 non-null    float64
#  64  ME7 BM5     398 non-null    float64
#  65  ME7 BM6     398 non-null    float64
#  66  ME7 BM7     398 non-null    float64
#  67  ME7 BM8     398 non-null    float64
#  68  ME7 BM9     398 non-null    float64
#  69  ME7 BM10    398 non-null    float64
#  70  ME8 BM1     398 non-null    float64
#  71  ME8 BM2     398 non-null    float64
#  72  ME8 BM3     398 non-null    float64
#  73  ME8 BM4     398 non-null    float64
#  74  ME8 BM5     398 non-null    float64
#  75  ME8 BM6     398 non-null    float64
#  76  ME8 BM7     398 non-null    float64
#  77  ME8 BM8     398 non-null    float64
#  78  ME8 BM9     398 non-null    float64
#  79  ME8 BM10    398 non-null    float64
#  80  ME9 BM1     398 non-null    float64
#  81  ME9 BM2     398 non-null    float64
#  82  ME9 BM3     398 non-null    float64
#  83  ME9 BM4     398 non-null    float64
#  84  ME9 BM5     398 non-null    float64
#  85  ME9 BM6     398 non-null    float64
#  86  ME9 BM7     398 non-null    float64
#  87  ME9 BM8     398 non-null    float64
#  88  ME9 BM9     398 non-null    float64
#  89  BIG LoBM    398 non-null    float64
#  90  ME10 BM2    398 non-null    float64
#  91  ME10 BM3    398 non-null    float64
#  92  ME10 BM4    398 non-null    float64
#  93  ME10 BM5    398 non-null    float64
#  94  ME10 BM6    398 non-null    float64
#  95  ME10 BM7    398 non-null    float64
#  96  ME10 BM8    398 non-null    float64
#  97  ME10 BM9    398 non-null    float64
#  98  BIG HiBM    398 non-null    float64
# dtypes: float64(99)
# memory usage: 310.9 KB

# %% [markdown]
# # Defining Parameter

# %%
# Size of Scaling Window
training_window_size = 252

# Range of Lambda Values for Cross-Validation
alpha = np.logspace(-8, 8, 100)
best_alpha_LASSO = 0
best_alpha_Ridge = 0

# Test dates
return_dates = df.index.to_list()[252:]

# To store results for predicted returns
predicted_returns = {
    'EW': [],
    'MinVar': [],
    'Ridge': [],
    'LASSO': [],
    'Constrained-LASSO': []
}

# To store results for sharpe ratio
sharpe_ratios = {
    'EW': 0,
    'MinVar': 0,
    'Ridge': 0,
    'LASSO': 0,
    'Constrained-LASSO': 0
}

# %% [markdown]
# # Defining Function

# %%
# Sharpe Ratio
def sharpe_ratio(test_return):
    avg_test_return = np.mean(test_return)
    stddev_test_return = np.std(test_return)
    return avg_test_return / stddev_test_return

# %%
# Equation for adjusted weightage for different models (OLS, LassoCV, RidgeCV)
def w_adjusted(train_data, model):
    # Declare global variables to store best alpha for LassoCV and RidgeCV
    global best_alpha_Ridge, best_alpha_LASSO

    # Demean training data without standardization
    train_data_demeaned = scale(train_data, with_mean=True, with_std=False)

    # Number of stocks
    N_stocks = len(train_data.columns)

    # Define equal weights
    equal_weight = np.ones(N_stocks) / N_stocks

    # Define matrix, N, for weight adjustments (sum constraint)
    N = np.eye(N_stocks - 1)  # Identity matrix of N_stocks - 1 size
    N = np.vstack([N, -1 * np.ones(N_stocks - 1)])  # Append row for sum constraint, making N matrix (N_stocks, N_stocks - 1)

    y = train_data_demeaned @ equal_weight
    X = train_data_demeaned @ N

    if model == 'LinearRegression':
        current_model = LinearRegression(fit_intercept=False).fit(X, y)
    if model == 'RidgeCV':
        current_model = RidgeCV(alphas=alpha, cv=5, fit_intercept=False).fit(X, y)
        best_alpha_Ridge = current_model.alpha_
    if model == 'LassoCV':
        current_model = LassoCV(alphas=alpha, cv=5, max_iter=5000, fit_intercept=False).fit(X, y)
        best_alpha_LASSO = current_model.alpha_
        
    beta = current_model.coef_

    w_adjusted = equal_weight - np.dot(N, beta)

    return w_adjusted

# %% [markdown]
# # OLS (First 6 assets): Adjusted Weightage & Predicted Return on 2024-01-02

# %%
# To retrieve data for the first 252 rows, and the first 6 columns (i.e., assets)
train_data = df.iloc[0:252, :6]

# To calculate the adjusted weightage, based on the model used
adj_weightage = w_adjusted(train_data, 'LinearRegression')

# Retrieve the real-time return for the next day
next_day_return = df.iloc[252, :6].values

# Calculate next-day (i.e., 2024-01-02) return using the predicted weightage
portfolio_return = np.dot(adj_weightage, next_day_return)

print('Adjusted weightage for first 6 assets: ', adj_weightage)
print('Min-Var portfolio return [first 6 assets]: ', portfolio_return)
# Out:
# Adjusted weightage for first 6 assets:  [ 0.13610383  0.25476295 -0.0921509   0.15418786  0.22985689  0.31723938]
# Min-Var portfolio return [first 6 assets]:  0.7731660277814977

# %% [markdown]
# # Equal-Weightage Portfolio (99 Assets)

# %%
for i in range (training_window_size, len(df)):
    # Amount of assets
    N_stocks = len(df.columns)

    # Equal weights for the portfolio
    equal_weight = np.ones(N_stocks) / N_stocks

    # Retrieve the real-time return for the next day
    next_day_return = df.iloc[i].values

    # Calculate next-day (i.e., 2024-01-02) return using the predicted weightage
    portfolio_return = np.dot(equal_weight, next_day_return)

    # Store predicted returns
    predicted_returns['EW'].append(portfolio_return)

print('EW Return Table:\n', pd.DataFrame(data=predicted_returns, index=return_dates, columns=['EW']))

sharpe_ratios['EW'] = sharpe_ratio(predicted_returns['EW'])
print('EW Sharpe Ratio: ', sharpe_ratios['EW'])
# Out:
# EW Return Table:
#                    EW
# 2024-01-02 -0.376465
# 2024-01-03 -2.217576
# 2024-01-04 -0.064040
# 2024-01-05 -0.021919
# 2024-01-08  1.697778
# ...              ...
# 2024-07-25  1.122424
# 2024-07-26  1.614141
# 2024-07-29 -0.727677
# 2024-07-30  0.229192
# 2024-07-31  0.571313
#
# [146 rows x 1 columns]
# EW Sharpe Ratio:  0.06540829983611159

# %% [markdown]
# # Min-Var Portfolio (99 Assets)

# %%
for i in range(training_window_size, len(df)):

    # Defining training period
    train_data = df.iloc[i-training_window_size:i]

    # To calculate the adjusted weightage, based on the model used
    adj_weightage = w_adjusted(train_data, 'LinearRegression')

    # Retrieve the real-time return for the next day
    next_day_return = df.iloc[i].values

    # Calculate next-day (i.e., 2024-01-02) return using the predicted weightage
    portfolio_return = np.dot(adj_weightage, next_day_return)

    # Store predicted returns
    predicted_returns['MinVar'].append(portfolio_return)

print('MinVar Return Table:\n', pd.DataFrame(data=predicted_returns, index=return_dates, columns=['MinVar']))

sharpe_ratios['MinVar'] = sharpe_ratio(predicted_returns['MinVar'])
print('MinVar Sharpe Ratio: ', sharpe_ratios['MinVar'])
# Out:
# MinVar Return Table:
#                MinVar
# 2024-01-02  1.742367
# 2024-01-03 -0.812425
# 2024-01-04 -0.301904
# 2024-01-05  0.114314
# 2024-01-08  0.961189
# ...              ...
# 2024-07-25 -0.616636
# 2024-07-26  0.943585
# 2024-07-29 -0.103261
# 2024-07-30 -0.457016
# 2024-07-31  1.260733
#
# [146 rows x 1 columns]
# MinVar Sharpe Ratio:  0.00758241850160112

# %% [markdown]
# # Ridge Portfolio (99 Assets)

# %%
for i in range(training_window_size, len(df)):

    # Defining training period
    train_data = df.iloc[i-training_window_size:i]

    # To calculate the adjusted weightage, based on the model used
    adj_weightage = w_adjusted(train_data, 'RidgeCV')

    # Retrieve the real-time return for the next day
    next_day_return = df.iloc[i].values

    # Calculate next-day (i.e., 2024-01-02) return using the predicted weightage
    portfolio_return = np.dot(adj_weightage, next_day_return)

    # Store predicted returns
    predicted_returns['Ridge'].append(portfolio_return)

print("Final lambda (alpha) used in RidgeCV: ", best_alpha_Ridge, '\n')
print('Ridge Return Table:\n', pd.DataFrame(data=predicted_returns, index=return_dates, columns=['Ridge']))

sharpe_ratios['Ridge'] = sharpe_ratio(predicted_returns['Ridge'])
print('Ridge Sharpe Ratio: ', sharpe_ratios['Ridge'])
# Out:
# Final lambda (alpha) used in RidgeCV:  104.76157527896662
#
# Ridge Return Table:
#                 Ridge
# 2024-01-02  1.522888
# 2024-01-03 -0.491125
# 2024-01-04 -0.399170
# 2024-01-05  0.132758
# 2024-01-08  0.834212
# ...              ...
# 2024-07-25 -0.359387
# 2024-07-26  1.388059
# 2024-07-29  0.126964
# 2024-07-30 -0.184015
# 2024-07-31  0.633287
#
# [146 rows x 1 columns]
# Ridge Sharpe Ratio:  0.1013248696436384

# %% [markdown]
# # LASSO Portfolio (99 Assets)

# %%
for i in range(training_window_size, len(df)):

    # Defining training period
    train_data = df.iloc[i-training_window_size:i]

    # To calculate the adjusted weightage, based on the model used
    adj_weightage = w_adjusted(train_data, 'LassoCV')

    # Retrieve the real-time return for the next day
    next_day_return = df.iloc[i].values

    # Calculate next-day (i.e., 2024-01-02) return using the predicted weightage
    portfolio_return = np.dot(adj_weightage, next_day_return)

    # Store predicted returns
    predicted_returns['LASSO'].append(portfolio_return)
    
print("Final lambda (alpha) used in LassoCV: ", best_alpha_LASSO, '\n')
print('LASSO Return Table:\n', pd.DataFrame(data=predicted_returns, index=return_dates, columns=['LASSO']))

sharpe_ratios['LASSO'] = sharpe_ratio(predicted_returns['LASSO'])
print('LASSO Sharpe Ratio: ', sharpe_ratios['LASSO'])
# Out:
# Final lambda (alpha) used in LassoCV:  0.029150530628251816
#
# LASSO Return Table:
#                 LASSO
# 2024-01-02  1.405719
# 2024-01-03 -0.384078
# 2024-01-04 -0.604772
# 2024-01-05  0.114279
# 2024-01-08  0.767850
# ...              ...
# 2024-07-25 -0.071232
# 2024-07-26  1.641609
# 2024-07-29  0.125146
# 2024-07-30 -0.225694
# 2024-07-31  0.934691
#
# [146 rows x 1 columns]
# LASSO Sharpe Ratio:  0.11058695714342875

# %% [markdown]
# # Exploration: Constrained Mean-Variance Portfolio

# %% [markdown]
# ### Defining Parameters

# %%
# Set limits on the total proportion of the portfolio allocated to high-volatility and low-volatility assets respectively
high_vol_limit = 0.4
low_vol_limit = 0.6

# Define the maximum weight that can be assigned to each high-volatility or low-volatility asset
upper_bound_high_vol = 0.1
upper_bound_low_vol = 1.0

# Tradeoff between risk and return (i.e., risk appetite)
risk_aversion_param = 0.5

# %%
# Extract Data
# Retrive daily return of each asset
asset_returns = df.values

# Using equal-weightage returns as the benchmark for market_returns
market_returns = np.mean(asset_returns, axis=1)

# Compute Mean Returns and Covariance Matrix
mean_returns = np.mean(asset_returns, axis=0)    # Expected return for each asset over the entire time period
cov_matrix = np.cov(asset_returns, rowvar=False) # Covariance matrix of asset returns (to calculate portfolio risk)

# %%
# Define Asset Classes
betas = [np.cov(asset_returns[:, i], market_returns)[0][1] / np.var(market_returns) for i in range(asset_returns.shape[1])]
high_vol_assets = [i for i, beta in enumerate(betas) if beta > 1]
low_vol_assets = [i for i, beta in enumerate(betas) if beta <= 1]

# %% [markdown]
# ### Create Model

# %%
# Create Model
def optimize_portfolio(mean_returns, cov_matrix, high_vol_assets, low_vol_assets, regularization_type="None"):
    num_assets = len(mean_returns)
    model = gp.Model("Constrained Portfolio Optimization")

    # Variables: weights for each asset
    weights = model.addVars(num_assets, lb=0, name="weights")

    # Objective: Minimize risk_aversion_param * (w.T * cov_matrix * w) - (1 - risk_aversion_param) * (w.T * mean_returns)
    portfolio_return = gp.quicksum(weights[i] * mean_returns[i] for i in range(num_assets))
    portfolio_risk = gp.quicksum(weights[i] * cov_matrix[i, j] * weights[j] for i in range(num_assets) for j in range(num_assets))

    # Add LASSO or Ridge Regularization
    # Penalty level for Constrained-LASSO and Constrained-Ridge, retrieved from previous results of LassoCV (best_alpha_LASSO) and RidgeCV (best_alpha_Ridge)
    if regularization_type == "LASSO":
        # Auxiliary variables for LASSO regularization
        abs_weights = model.addVars(num_assets, name="abs_weights")
        # Add constraints to link abs_weights with weights
        for i in range(num_assets):
            model.addConstr(abs_weights[i] >= weights[i], name=f"abs_weight_pos_{i}")
            model.addConstr(abs_weights[i] >= -weights[i], name=f"abs_weight_neg_{i}")
        regularization_term = gp.quicksum(best_alpha_LASSO * abs_weights[i] for i in range(num_assets))
    elif regularization_type == "Ridge":
        regularization_term = gp.quicksum(best_alpha_Ridge * (weights[i] * weights[i]) for i in range(num_assets))
    else:
        regularization_term = 0

    # Set Objective: Minimize risk + regularization - expected return
    model.setObjective(risk_aversion_param * portfolio_risk - (1 - risk_aversion_param) * portfolio_return + regularization_term, GRB.MINIMIZE)

    # Constraint: Fully invested constraint (sum(weights) = 1)
    model.addConstr(weights.sum() == 1, "fully_invested")

    # Constraints: Class constraints
    high_vol_weight = gp.quicksum(weights[i] for i in high_vol_assets)
    low_vol_weight = gp.quicksum(weights[i] for i in low_vol_assets)
    model.addConstr(high_vol_weight <= high_vol_limit, "high_vol_limit")
    model.addConstr(low_vol_weight >= low_vol_limit, "low_vol_limit")

    # Bounds for each asset class
    for i in range(num_assets):
        if i in high_vol_assets:
            weights[i].setAttr(GRB.Attr.UB, upper_bound_high_vol)
        else:
            weights[i].setAttr(GRB.Attr.UB, upper_bound_low_vol)

    # Solve
    model.optimize()

    if model.status == GRB.OPTIMAL:
        optimal_weights = model.getAttr('x', weights)
        return [optimal_weights[i] for i in range(num_assets)]
    else:
        print("No optimal solution found.")
        return None

# %% [markdown]
# ### LASSO Regularization with Portfolio Weight Constraints

# %%
for i in range(training_window_size, len(df)):
    # Define training period
    train_data = df.iloc[i-training_window_size:i]

    # Compute mean returns and covariance matrix for training period
    mean_returns_train = np.mean(train_data, axis=0)
    cov_matrix_train = np.cov(train_data, rowvar=False)

    # Optimize portfolio for training period with LASSO regularization
    adjusted_weights = optimize_portfolio(mean_returns_train, cov_matrix_train, high_vol_assets, low_vol_assets, regularization_type="LASSO")

    # Calculate next-day return using predicted weights
    next_day_return = asset_returns[i]
    if adjusted_weights is not None:
        portfolio_return = np.dot(adjusted_weights, next_day_return)
    else:
        predicted_return = 0  # Fallback if no optimal solution found

    # Store predicted returns
    predicted_returns['Constrained-LASSO'].append(portfolio_return)

# Display Predicted Returns and Sharpe Ratio
print('Constrained-LASSO Return Table:\n', pd.DataFrame(data=predicted_returns, index=return_dates, columns=['Constrained-LASSO']))

sharpe_ratios['Constrained-LASSO'] = sharpe_ratio(predicted_returns['Constrained-LASSO'])
print('Constrained-LASSO Sharpe Ratio: ', sharpe_ratios['Constrained-LASSO'])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-09
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xebb72b4e
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-03, 1e-01]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.01973431e+04 -6.34896235e+04  9.85e+04 1.11e-01  6.77e+05     0s
#    1   1.01178873e+05 -1.04010225e+05  7.75e+03 5.81e+01  5.66e+04     0s
#    2   2.23573476e+03 -4.71462674e+03  2.86e+02 1.36e+00  2.19e+03     0s
#    3   4.08078730e-01 -2.33860793e+03  1.05e+00 3.85e-09  3.11e+01     0s
#    4   6.00446226e-01 -1.53628328e+02  1.05e-06 7.49e-13  1.54e+00     0s
#    5   5.97167694e-01 -1.34710130e+00  1.07e-08 3.47e-13  1.94e-02     0s
#    6   4.66843439e-01 -1.00469770e-01  3.15e-10 1.04e-14  5.67e-03     0s
#    7   3.38140096e-01  1.50026673e-01  2.00e-15 1.20e-15  1.88e-03     0s
#    8   2.78369199e-01  2.48874316e-01  2.78e-16 1.54e-15  2.95e-04     0s
#    9   2.63946598e-01  2.62851842e-01  5.00e-16 1.55e-15  1.09e-05     0s
#   10   2.63264876e-01  2.63253340e-01  6.00e-15 1.39e-15  1.15e-07     0s
#   11   2.63255687e-01  2.63255549e-01  9.95e-14 1.80e-15  1.38e-09     0s
#   12   2.63255552e-01  2.63255552e-01  1.39e-12 1.41e-15  1.38e-12     0s
#
# Barrier solved model in 12 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 2.63255552e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x1ac77e35
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e-04, 9e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.52930152e+04 -1.61735833e+04  9.82e+04 3.74e-01  6.77e+05     0s
#    1   2.86856874e+04 -2.94137349e+04  5.90e+03 8.61e-06  4.32e+04     0s
#    2   1.98551052e+03 -2.64258307e+03  3.45e+02 5.04e-07  2.73e+03     0s
#    3   2.83095519e-01 -5.95645266e+02  2.29e+00 3.35e-09  4.18e+01     0s
#    4   5.01076110e-01 -9.41644922e+01  2.29e-06 1.06e-12  3.79e+00     0s
#    5   4.97087049e-01 -4.39211357e-01  1.56e-08 5.48e-13  3.75e-02     0s
#    6   3.53525086e-01  9.69622188e-02  1.53e-14 5.36e-15  1.03e-02     0s
#    7   2.82111093e-01  2.50881645e-01  2.00e-15 4.16e-15  1.25e-03     0s
#    8   2.63727732e-01  2.60939515e-01  2.28e-15 6.99e-15  1.12e-04     0s
#    9   2.62102278e-01  2.62078625e-01  2.44e-15 9.34e-15  9.46e-07     0s
#   10   2.62087902e-01  2.62087427e-01  2.07e-14 6.00e-15  1.90e-08     0s
#   11   2.62087630e-01  2.62087628e-01  1.04e-11 7.08e-15  8.97e-11     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.62087630e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x18c47143
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-03, 8e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.39132629e+04 -6.49287276e+04  9.85e+04 1.54e-01  6.77e+05     0s
#    1   5.59734116e+04 -5.73700296e+04  6.24e+03 8.10e+00  4.59e+04     0s
#    2   2.14667522e+03 -3.41842267e+03  3.44e+02 2.70e-07  2.68e+03     0s
#    3   3.46166534e-01 -1.18551290e+03  7.67e-01 6.02e-10  2.96e+01     0s
#    4   5.00655054e-01 -5.34247190e+01  7.67e-07 5.74e-13  1.08e+00     0s
#    5   4.94948258e-01  1.04520427e-02  2.99e-09 2.32e-13  9.69e-03     0s
#    6   3.17965635e-01  1.27412746e-01  2.22e-15 3.11e-15  3.81e-03     0s
#    7   2.74038828e-01  2.55647439e-01  4.44e-16 2.24e-15  3.68e-04     0s
#    8   2.65259389e-01  2.62140730e-01  7.05e-15 3.39e-15  6.24e-05     0s
#    9   2.63593086e-01  2.63583188e-01  4.77e-15 3.98e-15  1.98e-07     0s
#   10   2.63585418e-01  2.63585330e-01  3.11e-14 2.30e-15  1.74e-09     0s
#   11   2.63585333e-01  2.63585332e-01  9.85e-13 3.68e-15  1.74e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.63585333e-01
# /var/folders/j5/m90b2sqx6k9dr4l9ys0fgx300000gn/T/ipykernel_25296/2123043764.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   portfolio_return = gp.quicksum(weights[i] * mean_returns[i] for i in range(num_assets))
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x89bc37c9
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e-18, 9e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.29539456e+04 -6.51786814e+04  9.85e+04 7.49e-02  6.77e+05     0s
#    1   1.01290439e+05 -1.04038689e+05  7.77e+03 5.81e+01  5.67e+04     0s
#    2   2.29756325e+03 -4.77575647e+03  2.82e+02 1.32e+00  2.16e+03     0s
#    3   4.31626713e-01 -2.33829197e+03  9.97e-01 1.02e-09  3.08e+01     0s
#    4   6.05152071e-01 -1.44825146e+02  9.97e-07 6.30e-13  1.45e+00     0s
#    5   6.01750994e-01 -9.06894846e-01  7.79e-09 2.61e-13  1.51e-02     0s
#    6   4.41478551e-01 -2.31958298e-02  1.71e-10 6.20e-15  4.65e-03     0s
#    7   3.21203222e-01  1.98941635e-01  6.22e-15 1.38e-15  1.22e-03     0s
#    8   2.73975847e-01  2.59028477e-01  3.00e-15 2.05e-15  1.49e-04     0s
#    9   2.64898175e-01  2.64485657e-01  6.33e-15 1.64e-15  4.13e-06     0s
#   10   2.64637456e-01  2.64633170e-01  1.34e-14 1.40e-15  4.29e-08     0s
#   11   2.64633911e-01  2.64633820e-01  3.48e-13 1.28e-15  9.06e-10     0s
#   12   2.64633822e-01  2.64633822e-01  4.44e-12 1.59e-15  8.98e-13     0s
#
# Barrier solved model in 12 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.64633822e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x1564bba0
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [9e-04, 8e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.57841593e+04 -1.58648745e+04  9.82e+04 2.79e-01  6.77e+05     0s
#    1   2.89159585e+04 -2.95985819e+04  5.89e+03 7.13e-06  4.32e+04     0s
#    2   1.98132830e+03 -2.63653660e+03  3.42e+02 4.14e-07  2.72e+03     0s
#    3   3.23962793e-01 -5.95231065e+02  2.34e+00 2.83e-09  4.22e+01     0s
#    4   4.94537146e-01 -9.65574774e+01  2.34e-06 1.63e-12  3.88e+00     0s
#    5   4.90749130e-01 -4.03441125e-01  1.53e-08 4.52e-13  3.58e-02     0s
#    6   3.46339258e-01  1.57224025e-01  3.02e-12 4.68e-15  7.56e-03     0s
#    7   2.80807967e-01  2.54194142e-01  1.93e-14 5.16e-15  1.06e-03     0s
#    8   2.65960951e-01  2.64557680e-01  4.11e-15 8.00e-15  5.61e-05     0s
#    9   2.64747118e-01  2.64728036e-01  2.18e-14 3.77e-15  7.63e-07     0s
#   10   2.64734344e-01  2.64734188e-01  4.26e-14 9.73e-15  6.24e-09     0s
#   11   2.64734197e-01  2.64734197e-01  3.49e-12 6.95e-15  1.59e-11     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.64734197e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xe357d5d3
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-04, 9e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.30842667e+04 -6.42643342e+04  9.85e+04 1.74e-01  6.77e+05     0s
#    1   5.63128504e+04 -5.77237018e+04  6.19e+03 7.24e+00  4.55e+04     0s
#    2   2.07920057e+03 -3.35017194e+03  3.30e+02 2.20e-07  2.57e+03     0s
#    3   3.60938123e-01 -1.18223206e+03  7.40e-01 4.93e-10  2.93e+01     0s
#    4   5.11877755e-01 -5.09139279e+01  7.40e-07 8.25e-13  1.03e+00     0s
#    5   5.05837831e-01 -5.98726369e-02  4.23e-09 2.64e-13  1.13e-02     0s
#    6   3.20488698e-01  1.43879193e-01  4.22e-15 3.16e-15  3.53e-03     0s
#    7   2.70041936e-01  2.54115588e-01  2.22e-16 2.51e-15  3.19e-04     0s
#    8   2.59708013e-01  2.59148038e-01  3.46e-14 3.73e-15  1.12e-05     0s
#    9   2.59217068e-01  2.59212983e-01  3.84e-14 3.37e-15  8.17e-08     0s
#   10   2.59213298e-01  2.59213256e-01  8.66e-13 3.01e-15  8.50e-10     0s
#   11   2.59213258e-01  2.59213258e-01  6.80e-13 3.89e-15  8.47e-13     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.59213258e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x31ea85e5
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-05, 8e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.30288989e+04 -6.36450579e+04  9.85e+04 1.57e-01  6.77e+05     0s
#    1   5.62095999e+04 -5.75862896e+04  6.19e+03 7.34e+00  4.55e+04     0s
#    2   2.09030425e+03 -3.35992209e+03  3.31e+02 3.51e-07  2.58e+03     0s
#    3   3.60767123e-01 -1.18247709e+03  7.41e-01 7.86e-10  2.93e+01     0s
#    4   5.08502688e-01 -5.09819027e+01  7.41e-07 9.95e-13  1.03e+00     0s
#    5   5.02428808e-01 -5.41961155e-02  4.09e-09 3.06e-13  1.11e-02     0s
#    6   3.16074272e-01  1.41355811e-01  4.00e-15 1.78e-15  3.49e-03     0s
#    7   2.66733565e-01  2.52435838e-01  1.67e-16 2.50e-15  2.86e-04     0s
#    8   2.57228610e-01  2.56720963e-01  1.37e-14 3.89e-15  1.02e-05     0s
#    9   2.56784483e-01  2.56778466e-01  1.02e-13 6.47e-15  1.20e-07     0s
#   10   2.56778832e-01  2.56778777e-01  9.00e-13 3.34e-15  1.10e-09     0s
#   11   2.56778780e-01  2.56778780e-01  9.32e-13 3.14e-15  1.10e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.56778780e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x544f192c
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-04, 8e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.36122036e+04 -6.53468666e+04  9.85e+04 7.28e-02  6.77e+05     0s
#    1   1.01748317e+05 -1.04465030e+05  7.63e+03 5.71e+01  5.58e+04     0s
#    2   2.17914448e+03 -4.65520747e+03  2.68e+02 1.23e+00  2.06e+03     0s
#    3   4.35355764e-01 -2.33583843e+03  8.63e-01 1.04e-09  2.98e+01     0s
#    4   5.86761713e-01 -1.20961408e+02  8.63e-07 6.65e-13  1.22e+00     0s
#    5   5.83022189e-01 -2.95852605e-01  3.65e-09 1.84e-13  8.79e-03     0s
#    6   3.64963952e-01  9.24379614e-02  3.11e-15 1.44e-15  2.73e-03     0s
#    7   2.79205561e-01  2.41524912e-01  2.78e-16 1.53e-15  3.77e-04     0s
#    8   2.58123352e-01  2.55652966e-01  1.75e-14 1.44e-15  2.47e-05     0s
#    9   2.56128635e-01  2.56096673e-01  5.66e-14 1.66e-15  3.20e-07     0s
#   10   2.56100326e-01  2.56099386e-01  1.23e-12 1.37e-15  9.40e-09     0s
#   11   2.56099410e-01  2.56099408e-01  8.35e-12 2.70e-15  2.19e-11     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.56099410e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xae94ba44
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.02s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.23854677e+04 -6.24571814e+04  9.85e+04 1.41e-01  6.77e+05     0s
#    1   5.59914690e+04 -5.73361844e+04  6.19e+03 6.15e+00  4.55e+04     0s
#    2   2.10896740e+03 -3.37671200e+03  3.36e+02 8.48e-07  2.62e+03     0s
#    3   3.65803409e-01 -1.18318914e+03  7.33e-01 1.85e-09  2.92e+01     0s
#    4   5.07646788e-01 -5.02864374e+01  7.33e-07 1.19e-12  1.02e+00     0s
#    5   5.01542428e-01 -1.55267492e-02  3.54e-09 1.61e-13  1.03e-02     0s
#    6   3.12705321e-01  1.12629666e-01  3.77e-15 3.44e-15  4.00e-03     0s
#    7   2.67793456e-01  2.49552901e-01  1.11e-16 2.37e-15  3.65e-04     0s
#    8   2.57797290e-01  2.57092533e-01  1.60e-14 4.43e-15  1.41e-05     0s
#    9   2.57241739e-01  2.57236367e-01  3.60e-14 3.42e-15  1.07e-07     0s
#   10   2.57236767e-01  2.57236696e-01  1.12e-12 3.66e-15  1.42e-09     0s
#   11   2.57236697e-01  2.57236697e-01  3.16e-11 3.79e-15  1.41e-12     0s
#
# Barrier solved model in 11 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 2.57236697e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xa315941b
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e-04, 6e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.28469886e+04 -6.38190283e+04  9.85e+04 6.48e-02  6.77e+05     0s
#    1   1.01412402e+05 -1.04073906e+05  7.59e+03 5.70e+01  5.55e+04     0s
#    2   2.17054924e+03 -4.64554939e+03  2.71e+02 1.24e+00  2.08e+03     0s
#    3   4.48382257e-01 -2.33740329e+03  8.55e-01 4.13e-09  2.97e+01     0s
#    4   5.90803491e-01 -1.19494828e+02  8.55e-07 1.11e-12  1.20e+00     0s
#    5   5.87033242e-01 -2.98378719e-01  3.73e-09 1.35e-13  8.85e-03     0s
#    6   3.67445493e-01  8.98298995e-02  3.55e-15 1.22e-15  2.78e-03     0s
#    7   2.80850687e-01  2.42462969e-01  2.22e-16 1.46e-15  3.84e-04     0s
#    8   2.59462551e-01  2.56790318e-01  5.22e-15 1.37e-15  2.67e-05     0s
#    9   2.57294702e-01  2.57262166e-01  3.30e-14 2.54e-15  3.25e-07     0s
#   10   2.57265893e-01  2.57264994e-01  1.14e-12 1.64e-15  8.99e-09     0s
#   11   2.57265032e-01  2.57265026e-01  3.19e-11 1.37e-15  6.52e-11     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.57265032e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xf5f527e4
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [9e-04, 6e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.34256292e+04 -6.38808460e+04  9.85e+04 6.25e-02  6.77e+05     0s
#    1   1.01780031e+05 -1.04408751e+05  7.54e+03 5.66e+01  5.51e+04     0s
#    2   2.13746363e+03 -4.61161407e+03  2.81e+02 1.31e+00  2.16e+03     0s
#    3   4.61922567e-01 -2.33968550e+03  9.25e-01 4.28e-09  3.03e+01     0s
#    4   6.06615314e-01 -1.31899869e+02  9.25e-07 1.08e-12  1.33e+00     0s
#    5   6.03009024e-01 -5.45124154e-01  5.44e-09 3.19e-13  1.15e-02     0s
#    6   4.05235807e-01  4.73722551e-02  7.90e-12 2.01e-15  3.58e-03     0s
#    7   2.98735244e-01  2.28093793e-01  7.77e-15 2.72e-15  7.06e-04     0s
#    8   2.64857249e-01  2.59184618e-01  1.33e-14 1.82e-15  5.67e-05     0s
#    9   2.60842143e-01  2.60778711e-01  6.00e-15 1.12e-15  6.34e-07     0s
#   10   2.60783503e-01  2.60782711e-01  3.54e-13 1.12e-15  7.91e-09     0s
#   11   2.60782721e-01  2.60782720e-01  7.02e-12 1.11e-15  7.81e-12     0s
#
# Barrier solved model in 11 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 2.60782721e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xa4553280
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.39876792e+04 -6.41480497e+04  9.85e+04 5.88e-02  6.77e+05     0s
#    1   1.01536307e+05 -1.04142035e+05  7.56e+03 5.67e+01  5.53e+04     0s
#    2   2.15192317e+03 -4.62546912e+03  2.81e+02 1.31e+00  2.15e+03     0s
#    3   4.67799587e-01 -2.33975493e+03  9.32e-01 4.52e-09  3.03e+01     0s
#    4   6.10813895e-01 -1.33053401e+02  9.32e-07 6.95e-13  1.34e+00     0s
#    5   6.07213553e-01 -5.78168258e-01  5.69e-09 1.89e-13  1.19e-02     0s
#    6   4.11705445e-01  4.10895404e-02  1.92e-11 1.60e-15  3.71e-03     0s
#    7   3.02293615e-01  2.26865737e-01  2.72e-15 1.28e-15  7.54e-04     0s
#    8   2.66584742e-01  2.60375910e-01  4.22e-15 1.61e-15  6.21e-05     0s
#    9   2.62200613e-01  2.62135628e-01  3.20e-14 1.53e-15  6.50e-07     0s
#   10   2.62139197e-01  2.62138988e-01  1.89e-13 2.60e-15  2.09e-09     0s
#   11   2.62138991e-01  2.62138991e-01  6.13e-13 1.86e-15  2.09e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.62138991e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xa6ed8dec
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.48295181e+03 -3.49223325e+03  9.81e+04 1.01e+00  6.77e+05     0s
#    1   7.12480975e+03 -7.18464815e+03  5.66e+03 4.26e-05  4.14e+04     0s
#    2   6.88801019e+02 -8.63039078e+02  2.60e+02 1.95e-06  2.14e+03     0s
#    3   1.20011781e+00 -1.54890881e+02  5.15e+00 3.88e-08  6.82e+01     0s
#    4   6.36383052e-01 -4.89180673e+01  5.15e-06 8.81e-13  7.93e+00     0s
#    5   6.26319784e-01 -2.25006903e+00  2.85e-07 9.36e-13  4.60e-01     0s
#    6   4.62711011e-01 -4.66487913e-01  2.85e-13 6.11e-14  1.49e-01     0s
#    7   3.35288567e-01  2.06555050e-01  2.22e-16 2.51e-14  2.06e-02     0s
#    8   2.74521061e-01  2.47413196e-01  2.10e-14 2.07e-14  4.34e-03     0s
#    9   2.60618441e-01  2.59938150e-01  2.39e-15 2.75e-14  1.09e-04     0s
#   10   2.60024867e-01  2.60023414e-01  1.22e-14 4.22e-14  2.33e-07     0s
#   11   2.60023496e-01  2.60023495e-01  1.53e-13 3.64e-14  2.33e-10     0s
#
# Barrier solved model in 11 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 2.60023496e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x453111b3
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-05, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.28679335e+04 -6.35914410e+04  9.85e+04 7.32e-02  6.77e+05     0s
#    1   1.01391383e+05 -1.04037377e+05  7.57e+03 5.67e+01  5.53e+04     0s
#    2   2.14024806e+03 -4.61536537e+03  2.77e+02 1.28e+00  2.13e+03     0s
#    3   4.52143520e-01 -2.33927660e+03  9.02e-01 3.32e-09  3.01e+01     0s
#    4   5.97121264e-01 -1.27833813e+02  9.02e-07 8.76e-13  1.28e+00     0s
#    5   5.93463101e-01 -4.56951027e-01  4.80e-09 2.27e-13  1.05e-02     0s
#    6   3.85989572e-01  5.85013754e-02  4.88e-15 1.19e-15  3.27e-03     0s
#    7   2.83921602e-01  2.24850063e-01  4.77e-15 1.26e-15  5.91e-04     0s
#    8   2.53747852e-01  2.49847499e-01  8.10e-15 1.21e-15  3.90e-05     0s
#    9   2.50807421e-01  2.50777854e-01  2.84e-14 1.18e-15  2.96e-07     0s
#   10   2.50779034e-01  2.50778993e-01  2.22e-13 2.10e-15  4.11e-10     0s
#   11   2.50778994e-01  2.50778994e-01  2.99e-13 1.80e-15  4.11e-13     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.50778994e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x2e96cae0
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.25229320e+04 -6.25569010e+04  9.85e+04 1.60e-01  6.77e+05     0s
#    1   5.54463089e+04 -5.67896876e+04  6.20e+03 5.80e+00  4.55e+04     0s
#    2   2.13972183e+03 -3.40795109e+03  3.36e+02 1.32e-06  2.62e+03     0s
#    3   3.29867168e-01 -1.18431719e+03  1.06e+00 4.15e-09  3.17e+01     0s
#    4   5.12627997e-01 -7.97724290e+01  1.06e-06 9.12e-13  1.61e+00     0s
#    5   5.08514494e-01 -2.51845716e-01  6.68e-09 1.75e-13  1.52e-02     0s
#    6   3.31019668e-01  1.48094424e-01  6.00e-15 2.44e-15  3.66e-03     0s
#    7   2.63177333e-01  2.39205866e-01  3.55e-15 2.00e-15  4.79e-04     0s
#    8   2.48788459e-01  2.47796347e-01  6.49e-15 2.73e-15  1.98e-05     0s
#    9   2.48019879e-01  2.48017113e-01  2.19e-14 3.54e-15  5.53e-08     0s
#   10   2.48017338e-01  2.48017336e-01  2.86e-13 3.91e-15  5.56e-11     0s
#
# Barrier solved model in 10 iterations and 0.02 seconds (0.01 work units)
# Optimal objective 2.48017338e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x042ca264
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.30471041e+04 -6.26900161e+04  9.85e+04 1.42e-01  6.77e+05     0s
#    1   5.55256563e+04 -5.68444655e+04  6.20e+03 5.60e+00  4.55e+04     0s
#    2   2.14666679e+03 -3.41355472e+03  3.38e+02 1.11e-06  2.63e+03     0s
#    3   3.31726010e-01 -1.18441281e+03  1.06e+00 3.49e-09  3.18e+01     0s
#    4   5.09511665e-01 -8.02844127e+01  1.06e-06 8.06e-13  1.62e+00     0s
#    5   5.05453539e-01 -2.45795033e-01  6.56e-09 4.41e-13  1.50e-02     0s
#    6   3.28141474e-01  1.47921854e-01  6.66e-15 2.90e-15  3.60e-03     0s
#    7   2.62342347e-01  2.36255896e-01  1.14e-14 2.94e-15  5.22e-04     0s
#    8   2.47380717e-01  2.46242520e-01  4.94e-15 1.92e-15  2.28e-05     0s
#    9   2.46519078e-01  2.46515427e-01  1.51e-14 1.85e-15  7.30e-08     0s
#   10   2.46515712e-01  2.46515708e-01  1.91e-13 2.35e-15  7.33e-11     0s
#
# Barrier solved model in 10 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.46515712e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x1557f9d0
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.38072231e+04 -6.42565835e+04  9.85e+04 6.24e-02  6.77e+05     0s
#    1   1.01721911e+05 -1.04351352e+05  7.42e+03 5.55e+01  5.43e+04     0s
#    2   2.05772267e+03 -4.53337511e+03  2.66e+02 1.18e+00  2.04e+03     0s
#    3   4.57386006e-01 -2.33913180e+03  7.54e-01 1.43e-09  2.90e+01     0s
#    4   5.80470387e-01 -1.01520663e+02  7.54e-07 6.32e-13  1.02e+00     0s
#    5   5.76630146e-01 -2.30055854e-01  3.84e-09 2.21e-13  8.07e-03     0s
#    6   3.35333733e-01  2.74867504e-02  3.55e-15 1.01e-15  3.08e-03     0s
#    7   2.67631258e-01  2.37334420e-01  2.22e-16 1.21e-15  3.03e-04     0s
#    8   2.48824631e-01  2.46991996e-01  9.10e-15 1.19e-15  1.83e-05     0s
#    9   2.47425119e-01  2.47411513e-01  4.02e-14 6.45e-16  1.36e-07     0s
#   10   2.47412249e-01  2.47412184e-01  9.95e-13 9.30e-16  6.46e-10     0s
#   11   2.47412185e-01  2.47412185e-01  5.60e-12 8.43e-16  7.48e-13     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.47412185e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x6c7f550e
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-05, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.36750200e+04 -6.43581366e+04  9.85e+04 6.37e-02  6.77e+05     0s
#    1   1.01906428e+05 -1.04554544e+05  7.38e+03 5.52e+01  5.40e+04     0s
#    2   2.03709540e+03 -4.51308340e+03  2.70e+02 1.22e+00  2.07e+03     0s
#    3   4.58386305e-01 -2.33991384e+03  7.86e-01 1.48e-09  2.92e+01     0s
#    4   5.85839924e-01 -1.07055336e+02  7.86e-07 1.02e-12  1.08e+00     0s
#    5   5.82122598e-01 -3.01026128e-01  4.32e-09 1.94e-13  8.83e-03     0s
#    6   3.52951605e-01  8.51555415e-02  4.44e-15 1.96e-15  2.68e-03     0s
#    7   2.67788695e-01  2.35539605e-01  4.44e-16 1.28e-15  3.22e-04     0s
#    8   2.48042358e-01  2.46155164e-01  1.55e-14 9.58e-16  1.89e-05     0s
#    9   2.46607417e-01  2.46593730e-01  1.40e-14 1.18e-15  1.37e-07     0s
#   10   2.46594501e-01  2.46594430e-01  2.79e-13 9.99e-16  7.07e-10     0s
#   11   2.46594431e-01  2.46594431e-01  2.58e-12 8.60e-16  7.50e-13     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.46594431e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x225b24ef
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.43108162e+04 -6.49757027e+04  9.85e+04 6.35e-02  6.77e+05     0s
#    1   1.01900326e+05 -1.04547121e+05  7.39e+03 5.52e+01  5.40e+04     0s
#    2   2.04028590e+03 -4.51589836e+03  2.71e+02 1.22e+00  2.08e+03     0s
#    3   4.58224455e-01 -2.33961816e+03  7.99e-01 1.66e-09  2.93e+01     0s
#    4   5.87134743e-01 -1.09368822e+02  7.99e-07 7.88e-13  1.10e+00     0s
#    5   5.83121288e-01 -1.93382509e-01  3.08e-09 2.13e-13  7.77e-03     0s
#    6   3.23495016e-01 -3.54267959e-02  3.11e-15 1.13e-15  3.59e-03     0s
#    7   2.66872487e-01  2.32376939e-01  3.33e-16 1.15e-15  3.45e-04     0s
#    8   2.48409519e-01  2.45745092e-01  1.09e-14 8.40e-16  2.66e-05     0s
#    9   2.46622372e-01  2.46603584e-01  1.87e-14 9.85e-16  1.88e-07     0s
#   10   2.46605146e-01  2.46604982e-01  7.42e-13 1.33e-15  1.64e-09     0s
#   11   2.46604984e-01  2.46604984e-01  5.47e-12 8.47e-16  1.84e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.46604984e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x3ea8bf46
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.41005219e+04 -6.49367768e+04  9.85e+04 6.48e-02  6.77e+05     0s
#    1   1.01858014e+05 -1.04518366e+05  7.29e+03 5.45e+01  5.34e+04     0s
#    2   2.00628928e+03 -4.48260353e+03  2.71e+02 1.23e+00  2.08e+03     0s
#    3   4.61370550e-01 -2.33997827e+03  8.39e-01 1.75e-09  2.96e+01     0s
#    4   5.95716758e-01 -1.16489138e+02  8.39e-07 6.26e-13  1.17e+00     0s
#    5   5.91808912e-01 -2.60546712e-01  3.53e-09 2.22e-13  8.52e-03     0s
#    6   3.42841673e-01  2.57763281e-02  3.11e-15 1.18e-15  3.17e-03     0s
#    7   2.67823185e-01  2.36846167e-01  4.44e-16 1.32e-15  3.10e-04     0s
#    8   2.48057863e-01  2.46114391e-01  4.11e-15 1.30e-15  1.94e-05     0s
#    9   2.46566438e-01  2.46551372e-01  2.60e-14 8.26e-16  1.51e-07     0s
#   10   2.46552468e-01  2.46552299e-01  3.97e-13 8.53e-16  1.68e-09     0s
#   11   2.46552301e-01  2.46552300e-01  1.95e-11 1.05e-15  1.68e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.46552301e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x066a8829
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-04, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.44218192e+04 -6.50111856e+04  9.85e+04 6.53e-02  6.77e+05     0s
#    1   1.01837510e+05 -1.04481552e+05  7.24e+03 5.41e+01  5.30e+04     0s
#    2   2.01137126e+03 -4.48794230e+03  2.72e+02 1.24e+00  2.09e+03     0s
#    3   4.67143025e-01 -2.34088585e+03  8.92e-01 1.82e-09  3.00e+01     0s
#    4   6.05429370e-01 -1.26029996e+02  8.92e-07 6.71e-13  1.27e+00     0s
#    5   6.01637215e-01 -4.19385818e-01  4.61e-09 2.41e-13  1.02e-02     0s
#    6   3.79350105e-01  5.49873776e-02  4.88e-15 1.94e-15  3.24e-03     0s
#    7   2.79095934e-01  2.18468733e-01  4.66e-15 1.60e-15  6.06e-04     0s
#    8   2.49034824e-01  2.44528596e-01  2.04e-14 1.08e-15  4.51e-05     0s
#    9   2.45789050e-01  2.45750564e-01  1.49e-14 8.19e-16  3.85e-07     0s
#   10   2.45752565e-01  2.45752414e-01  1.35e-13 5.97e-16  1.50e-09     0s
#   11   2.45752416e-01  2.45752416e-01  2.02e-12 1.08e-15  1.50e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.45752416e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xb662e6bc
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-05, 7e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.43416256e+04 -6.47674656e+04  9.85e+04 6.59e-02  6.77e+05     0s
#    1   1.01842039e+05 -1.04479041e+05  7.17e+03 5.36e+01  5.25e+04     0s
#    2   1.99664640e+03 -4.47438364e+03  2.72e+02 1.24e+00  2.09e+03     0s
#    3   4.73605805e-01 -2.34185769e+03  8.92e-01 2.20e-09  3.00e+01     0s
#    4   6.12215233e-01 -1.26042594e+02  8.92e-07 7.49e-13  1.27e+00     0s
#    5   6.08307424e-01 -4.47464108e-01  4.84e-09 1.27e-13  1.06e-02     0s
#    6   3.85732741e-01  5.01844297e-02  4.88e-15 1.72e-15  3.36e-03     0s
#    7   2.82394015e-01  2.18420326e-01  1.11e-15 1.42e-15  6.40e-04     0s
#    8   2.51374935e-01  2.45758470e-01  3.77e-15 1.38e-15  5.62e-05     0s
#    9   2.47527915e-01  2.47486215e-01  2.11e-15 6.66e-16  4.17e-07     0s
#   10   2.47488206e-01  2.47488159e-01  9.16e-14 8.33e-16  4.65e-10     0s
#   11   2.47488161e-01  2.47488161e-01  6.32e-14 1.14e-15  4.66e-13     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.47488161e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xb43d4df0
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [8e-05, 8e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.61950177e+03 -3.59995453e+03  9.81e+04 1.03e+00  6.77e+05     0s
#    1   7.09377919e+03 -7.15126639e+03  5.65e+03 3.16e-05  4.13e+04     0s
#    2   6.78690187e+02 -8.53539690e+02  2.53e+02 1.42e-06  2.09e+03     0s
#    3   1.12884693e+00 -1.55252454e+02  5.07e+00 2.84e-08  6.77e+01     0s
#    4   6.26736658e-01 -4.84439333e+01  5.07e-06 7.57e-13  7.85e+00     0s
#    5   6.16983371e-01 -2.48404202e+00  3.07e-07 9.41e-13  4.96e-01     0s
#    6   4.51565555e-01 -6.38447516e-01  3.07e-13 7.17e-14  1.74e-01     0s
#    7   3.27216040e-01  1.86310788e-01  2.22e-16 5.86e-14  2.25e-02     0s
#    8   2.58784404e-01  2.40754491e-01  6.11e-15 2.35e-14  2.88e-03     0s
#    9   2.46752787e-01  2.46277141e-01  4.94e-15 2.35e-14  7.61e-05     0s
#   10   2.46340006e-01  2.46337523e-01  5.43e-14 9.99e-15  3.97e-07     0s
#   11   2.46337670e-01  2.46337650e-01  4.63e-12 1.20e-14  3.16e-09     0s
#   12   2.46337650e-01  2.46337650e-01  8.36e-12 1.21e-14  3.16e-12     0s
#
# Barrier solved model in 12 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 2.46337650e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xa7343dce
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-05, 8e-02]
#   QObjective range [6e-01, 7e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.36383616e+04 -6.34973810e+04  9.85e+04 5.93e-02  6.77e+05     0s
#    1   1.01399021e+05 -1.03994183e+05  7.20e+03 5.40e+01  5.27e+04     0s
#    2   2.00107738e+03 -4.47619049e+03  2.69e+02 1.22e+00  2.07e+03     0s
#    3   4.75760750e-01 -2.34072728e+03  8.25e-01 5.01e-09  2.95e+01     0s
#    4   6.00643015e-01 -1.14031916e+02  8.25e-07 7.73e-13  1.15e+00     0s
#    5   5.96598714e-01 -2.40029600e-01  3.44e-09 1.91e-13  8.37e-03     0s
#    6   3.35781883e-01 -8.50346400e-03  3.11e-15 2.04e-15  3.44e-03     0s
#    7   2.68503101e-01  2.35089736e-01  1.67e-16 1.54e-15  3.34e-04     0s
#    8   2.48153990e-01  2.45284537e-01  1.11e-14 9.71e-16  2.87e-05     0s
#    9   2.46169460e-01  2.46151333e-01  6.66e-15 8.88e-16  1.81e-07     0s
#   10   2.46153041e-01  2.46152797e-01  3.36e-13 9.82e-16  2.44e-09     0s
#   11   2.46152799e-01  2.46152799e-01  1.27e-11 1.20e-15  2.42e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 2.46152799e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# ...
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.27970748e+04 -9.33161114e+04  9.85e+04 2.19e-01  6.77e+05     0s
#    1   5.28468070e+04 -5.41997265e+04  6.56e+03 1.76e+01  4.80e+04     0s
#    2   2.53455090e+03 -3.81057606e+03  3.37e+02 3.12e-07  2.63e+03     0s
#    3   1.98417569e-01 -1.18878450e+03  1.06e+00 9.79e-10  3.19e+01     0s
#    4   3.74282675e-01 -8.04979447e+01  1.06e-06 7.81e-13  1.62e+00     0s
#    5   3.70672669e-01 -1.21659461e-01  3.22e-09 2.22e-13  9.85e-03     0s
#    6   2.19872008e-01  9.65600206e-02  3.33e-15 2.23e-15  2.47e-03     0s
#    7   1.77274876e-01  1.63854194e-01  4.44e-16 1.85e-15  2.68e-04     0s
#    8   1.68618037e-01  1.67803270e-01  6.97e-15 1.59e-15  1.63e-05     0s
#    9   1.68127318e-01  1.68117484e-01  1.05e-14 1.60e-15  1.97e-07     0s
#   10   1.68122553e-01  1.68122455e-01  7.19e-13 1.83e-15  1.96e-09     0s
#   11   1.68122547e-01  1.68122547e-01  8.68e-12 1.39e-15  1.95e-12     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 1.68122547e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xd2f60f33
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-03, 8e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.21294811e+04 -9.30601543e+04  9.85e+04 2.18e-01  6.77e+05     0s
#    1   5.28226932e+04 -5.42030087e+04  6.56e+03 1.75e+01  4.80e+04     0s
#    2   2.53502014e+03 -3.81240358e+03  3.38e+02 2.78e-07  2.63e+03     0s
#    3   1.95133809e-01 -1.18887958e+03  1.05e+00 8.67e-10  3.18e+01     0s
#    4   3.74794404e-01 -8.00535915e+01  1.05e-06 5.65e-13  1.61e+00     0s
#    5   3.71165162e-01 -1.29530084e-01  3.34e-09 1.78e-13  1.00e-02     0s
#    6   2.20075697e-01  9.67433000e-02  3.77e-15 1.75e-15  2.47e-03     0s
#    7   1.76855998e-01  1.62722335e-01  4.44e-16 1.44e-15  2.83e-04     0s
#    8   1.68057872e-01  1.67031887e-01  5.22e-15 1.40e-15  2.05e-05     0s
#    9   1.67449679e-01  1.67435959e-01  7.44e-15 1.55e-15  2.74e-07     0s
#   10   1.67443421e-01  1.67442767e-01  1.10e-12 1.55e-15  1.31e-08     0s
#   11   1.67443383e-01  1.67443378e-01  1.46e-11 1.65e-15  9.67e-11     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 1.67443383e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x4b8e667d
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-03, 8e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.18870028e+04 -9.29647013e+04  9.85e+04 2.15e-01  6.77e+05     0s
#    1   5.28314716e+04 -5.42199335e+04  6.52e+03 1.68e+01  4.77e+04     0s
#    2   2.52659180e+03 -3.80415905e+03  3.35e+02 3.17e-07  2.61e+03     0s
#    3   1.97306559e-01 -1.18901079e+03  1.06e+00 9.97e-10  3.18e+01     0s
#    4   3.76578022e-01 -8.02398515e+01  1.06e-06 7.93e-13  1.61e+00     0s
#    5   3.72988579e-01 -1.30042012e-01  3.38e-09 2.23e-13  1.01e-02     0s
#    6   2.22652302e-01  9.93197626e-02  3.77e-15 1.79e-15  2.47e-03     0s
#    7   1.79397748e-01  1.64894662e-01  6.66e-16 1.96e-15  2.90e-04     0s
#    8   1.70814404e-01  1.68570796e-01  6.66e-15 1.32e-15  4.49e-05     0s
#    9   1.69584819e-01  1.69568127e-01  5.33e-15 1.45e-15  3.34e-07     0s
#   10   1.69575159e-01  1.69573911e-01  3.59e-13 2.62e-15  2.50e-08     0s
#   11   1.69574210e-01  1.69574115e-01  2.05e-11 1.60e-15  1.90e-09     0s
#   12   1.69574120e-01  1.69574120e-01  6.79e-12 1.87e-15  6.78e-12     0s
#
# Barrier solved model in 12 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 1.69574120e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x47f03c6d
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-17, 8e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.23178499e+04 -9.42416217e+04  9.85e+04 1.00e-01  6.77e+05     0s
#    1   9.35466477e+04 -9.62544796e+04  8.07e+03 6.01e+01  5.87e+04     0s
#    2   3.45980182e+03 -5.95311194e+03  3.15e+02 1.53e+00  2.42e+03     0s
#    3   2.70349945e-01 -2.34588107e+03  1.35e+00 1.13e-09  3.35e+01     0s
#    4   4.76820512e-01 -3.94778772e+02  1.10e-01 9.20e-11  4.18e+00     0s
#    5   4.87761307e-01 -1.47071078e+00  1.02e-05 6.17e-13  1.96e-02     0s
#    6   4.41846470e-01 -1.18499046e-01  2.56e-06 1.56e-13  5.60e-03     0s
#    7   2.25157043e-01 -1.73433901e-01  2.57e-12 6.45e-15  3.99e-03     0s
#    8   1.89289738e-01  1.60799991e-01  3.33e-14 1.66e-15  2.85e-04     0s
#    9   1.74972712e-01  1.71366039e-01  3.00e-15 8.33e-16  3.61e-05     0s
#   10   1.72034554e-01  1.71731948e-01  1.10e-14 9.89e-16  3.03e-06     0s
#   11   1.71848047e-01  1.71847736e-01  2.39e-15 8.74e-16  3.11e-09     0s
#   12   1.71847854e-01  1.71847854e-01  9.55e-15 9.23e-16  3.11e-12     0s
#
# Barrier solved model in 12 iterations and 0.02 seconds (0.01 work units)
# Optimal objective 1.71847854e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xcfa36e33
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-04, 8e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.03854742e+04 -9.13611251e+04  9.85e+04 2.14e-01  6.77e+05     0s
#    1   5.26205617e+04 -5.40030577e+04  6.50e+03 1.73e+01  4.76e+04     0s
#    2   2.51446079e+03 -3.79210939e+03  3.35e+02 2.50e-07  2.61e+03     0s
#    3   1.99908636e-01 -1.18920322e+03  1.08e+00 8.08e-10  3.21e+01     0s
#    4   3.82752484e-01 -8.27725865e+01  1.08e-06 5.98e-13  1.66e+00     0s
#    5   3.79157291e-01 -1.28801629e-01  3.37e-09 2.56e-13  1.02e-02     0s
#    6   2.26518366e-01  8.22990440e-02  4.00e-15 2.84e-15  2.88e-03     0s
#    7   1.82859824e-01  1.68308087e-01  2.22e-16 2.03e-15  2.91e-04     0s
#    8   1.73538709e-01  1.71509874e-01  7.08e-15 1.79e-15  4.06e-05     0s
#    9   1.72369857e-01  1.72364150e-01  3.11e-15 2.41e-15  1.14e-07     0s
#   10   1.72365355e-01  1.72365349e-01  1.84e-14 1.90e-15  1.15e-10     0s
#
# Barrier solved model in 10 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 1.72365355e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x59aadcd6
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-03, 8e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.98464940e+04 -9.21979907e+04  9.85e+04 1.11e-01  6.77e+05     0s
#    1   9.30735288e+04 -9.58185627e+04  8.06e+03 6.00e+01  5.86e+04     0s
#    2   3.47234466e+03 -5.96693014e+03  3.15e+02 1.53e+00  2.42e+03     0s
#    3   2.64365680e-01 -2.34535176e+03  1.36e+00 8.25e-10  3.36e+01     0s
#    4   4.77742290e-01 -3.99373135e+02  1.12e-01 6.82e-11  4.24e+00     0s
#    5   4.89389922e-01 -1.64488598e+00  1.59e-05 5.81e-13  2.13e-02     0s
#    6   4.46225613e-01 -1.22586266e-01  3.80e-06 1.42e-13  5.69e-03     0s
#    7   2.29941755e-01 -1.46870427e-01  3.80e-12 4.84e-15  3.77e-03     0s
#    8   1.90302751e-01  1.65507205e-01  5.55e-15 1.66e-15  2.48e-04     0s
#    9   1.75477420e-01  1.72381293e-01  8.74e-15 7.15e-16  3.10e-05     0s
#   10   1.72775135e-01  1.72642273e-01  2.37e-14 1.03e-15  1.33e-06     0s
#   11   1.72691451e-01  1.72691316e-01  3.00e-15 7.03e-16  1.35e-09     0s
#   12   1.72691366e-01  1.72691366e-01  6.88e-15 1.05e-15  1.35e-12     0s
#
# Barrier solved model in 12 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 1.72691366e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0x73ee942d
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-04, 9e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.25185552e+04 -2.28875698e+04  9.83e+04 9.65e-01  6.77e+05     0s
#    1   1.50903728e+04 -1.54493105e+04  5.38e+03 3.19e-06  3.96e+04     0s
#    2   1.07637056e+03 -1.42037803e+03  2.68e+02 1.59e-07  2.19e+03     0s
#    3   3.98849846e-01 -3.05819787e+02  3.19e+00 1.89e-09  5.07e+01     0s
#    4   4.46283540e-01 -6.66761766e+01  3.19e-06 1.34e-12  5.37e+00     0s
#    5   4.37121999e-01 -3.97224538e-01  2.42e-08 1.35e-12  6.67e-02     0s
#    6   2.50047294e-01 -4.06352345e-02  2.44e-14 7.63e-15  2.33e-02     0s
#    7   1.89685979e-01  1.55426642e-01  1.11e-16 4.66e-15  2.74e-03     0s
#    8   1.73114026e-01  1.68857615e-01  9.08e-15 6.99e-15  3.41e-04     0s
#    9   1.70483170e-01  1.69965646e-01  1.22e-15 1.05e-14  4.14e-05     0s
#   10   1.70168071e-01  1.70166785e-01  8.88e-15 7.66e-15  1.03e-07     0s
#   11   1.70167002e-01  1.70167001e-01  9.25e-14 8.70e-15  1.03e-10     0s
#
# Barrier solved model in 11 iterations and 0.01 seconds (0.01 work units)
# Optimal objective 1.70167002e-01
#
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.0.0 24A348)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 201 rows, 198 columns and 594 nonzeros
# Model fingerprint: 0xe1835039
# Model has 4950 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-03, 9e-02]
#   QObjective range [1e-01, 6e+00]
#   Bounds range     [1e-01, 1e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 198 rows and 99 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 99 columns, 198 nonzeros
# Presolved model has 4950 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 98
#  AA' NZ     : 5.049e+03
#  Factor NZ  : 5.151e+03
#  Factor Ops : 3.486e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.17959554e+04 -9.40525305e+04  9.85e+04 1.28e-01  6.77e+05     0s
#    1   9.26162178e+04 -9.53515784e+04  8.10e+03 6.05e+01  5.90e+04     0s
#    2   3.52293679e+03 -6.01714608e+03  3.20e+02 1.57e+00  2.46e+03     0s
#    3   2.62149811e-01 -2.34616290e+03  1.35e+00 5.47e-10  3.35e+01     0s
#    4   4.74165932e-01 -3.92608669e+02  1.08e-01 4.38e-11  4.16e+00     0s
#    5   4.85363588e-01 -1.42905805e+00  9.84e-06 4.85e-13  1.91e-02     0s
#    6   4.39095613e-01 -1.36118908e-01  2.57e-06 1.23e-13  5.75e-03     0s
#    7   2.37396891e-01 -1.10183447e-01  2.57e-12 4.00e-15  3.48e-03     0s
#    8   1.89824911e-01  1.62748118e-01  1.33e-15 1.11e-15  2.71e-04     0s
#    9   1.73696794e-01  1.69506287e-01  2.42e-14 1.23e-15  4.19e-05     0s
#   10   1.70619261e-01  1.70015633e-01  9.66e-15 1.03e-15  6.04e-06     0s
#   11   1.70256813e-01  1.70255831e-01  5.00e-15 8.74e-16  9.83e-09     0s
#   12   1.70256087e-01  1.70256086e-01  2.21e-14 8.19e-16  9.88e-12     0s
#
# Barrier solved model in 12 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 1.70256087e-01
#
# Constrained-LASSO Return Table:
#              Constrained-LASSO
# 2024-01-02           0.529651
# 2024-01-03          -0.651303
# 2024-01-04          -0.433286
# 2024-01-05           0.204586
# 2024-01-08           0.883565
# ...                       ...
# 2024-07-25           0.015803
# 2024-07-26           1.251001
# 2024-07-29          -0.010590
# 2024-07-30           0.374379
# 2024-07-31           0.610266
#
# [146 rows x 1 columns]
# Constrained-LASSO Sharpe Ratio:  0.17122243364208564

# %% [markdown]
# # Result

# %%
# Predicted Returns for Each Portfolio
predicted_returns_df = pd.DataFrame(data=predicted_returns, index=return_dates)
print('Summary Return:\n', predicted_returns_df)
# Out:
# Summary Return:
#                    EW    MinVar     Ridge     LASSO  Constrained-LASSO
# 2024-01-02 -0.376465  1.742367  1.522888  1.405719           0.529651
# 2024-01-03 -2.217576 -0.812425 -0.491125 -0.384078          -0.651303
# 2024-01-04 -0.064040 -0.301904 -0.399170 -0.604772          -0.433286
# 2024-01-05 -0.021919  0.114314  0.132758  0.114279           0.204586
# 2024-01-08  1.697778  0.961189  0.834212  0.767850           0.883565
# ...              ...       ...       ...       ...                ...
# 2024-07-25  1.122424 -0.616636 -0.359387 -0.071232           0.015803
# 2024-07-26  1.614141  0.943585  1.388059  1.641609           1.251001
# 2024-07-29 -0.727677 -0.103261  0.126964  0.125146          -0.010590
# 2024-07-30  0.229192 -0.457016 -0.184015 -0.225694           0.374379
# 2024-07-31  0.571313  1.260733  0.633287  0.934691           0.610266
#
# [146 rows x 5 columns]

# %%
# Sharpe Ratio
sharpe_ratios_df = pd.DataFrame(data=sharpe_ratios, index=['Sharpe Ratio'])
print(sharpe_ratios_df)
# Out:
#                     EW    MinVar     Ridge     LASSO  Constrained-LASSO
# Sharpe Ratio  0.065408  0.007582  0.101325  0.110587           0.171222
